# %%
import cv2
import matplotlib.pyplot as plt

# %%
# load image
doc_img = cv2.imread("assets/personal/aadhar.jpg")
doc_img = cv2.cvtColor(doc_img, cv2.COLOR_BGR2RGB)

plt.figure()
plt.imshow(doc_img)
plt.axis("off")
plt.show()

# %%
# !pip install easyocr
# Out:
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.9 MB 10.2 MB/s eta 0:00:01
#    -------- ------------------------------- 0.6/2.9 MB 6.1 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/2.9 MB 5.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.8/2.9 MB 4.8 MB/s eta 0:00:01
#    ------------- -------------------------- 0.9/2.9 MB 4.3 MB/s eta 0:00:01
#    --------------- ------------------------ 1.1/2.9 MB 4.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.3/2.9 MB 4.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.4/2.9 MB 3.9 MB/s eta 0:00:01
#    --------------------- ------------------ 1.6/2.9 MB 4.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.7/2.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.9 MB 3.7 MB/s eta 0:00:01
# ...

# %%
import easyocr

# %%
img_path = 'assets/personal/aadhar.jpg'
reader = easyocr.Reader(['en'])
result = reader.readtext(img_path)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |█████████████████████████████████-----------------| 66.9% Complete

# %%
result
